# %%
import pickle
import numpy as np
from sklearn.externals import joblib
from flask import Flask, request,jsonify, render_template

def ValuePredictor(to_predict_list): 
    to_predict = np.array(to_predict_list).reshape(1,18)
    loaded_model = joblib.load(open("model.pkl", "rb")) 
    result = loaded_model.predict(to_predict) 
    return result[0] 
  
app=Flask(__name__)

@app.route('/') 
def index():
    return render_template('index.html')

@app.route('/result', methods = ['POST']) 
def result(): 
    if request.method == 'POST': 
        to_predict_list = request.form.to_dict() 
        to_predict_list = list(to_predict_list.values())
        to_predict_list = list(map(int, to_predict_list)) 
        result = ValuePredictor(to_predict_list)
        if int(result)== 1: 
            prediction ='Customer will CHURN'
            
        else: 
            prediction ='Customer will NOT CHURN'            
        return render_template("result.html", prediction = prediction,result=result) 

@app.route('/chart', methods = ['POST']) 
def chart():
    if request.method == 'POST':
        return render_template("chart.html",chart=chart) 
    
if __name__=="__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Jun/2020 20:07:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:07:33] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/js/jquery.steps.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/fonts/material-design-iconic-font/css/material-design-iconic-font.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/images/form-wizard-bg.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/js/jquery-3.3.1.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/fonts/poppins/Poppins-Regular.ttf HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/fonts/poppins/Poppins-SemiBold.ttf HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /static/fonts/poppins/Poppins-Medium.ttf HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:07:34] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Jun/2020 20:08:48] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:09:50] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:09:50] "GET /static/images/plt.png HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:10:11] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:10:30] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:11:11] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:11:26] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:13:51] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:13:55] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:14:07] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:15:26] "POST /chart HTTP/1.1" 200 -
# [2020-06-06 20:19:53,158] ERROR in app: Exception on /result [POST]
# Traceback (most recent call last):
#   File "C:\Users\manish\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\manish\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\manish\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\manish\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\Users\manish\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\manish\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-5cb057b93011>", line 24, in result
#     result = ValuePredictor(to_predict_list)
#   File "<ipython-input-1-5cb057b93011>", line 7, in ValuePredictor
#     to_predict = np.array(to_predict_list).reshape(1,18)
# ValueError: cannot reshape array of size 17 into shape (1,18)
# 127.0.0.1 - - [06/Jun/2020 20:19:53] "POST /result HTTP/1.1" 500 -
# 127.0.0.1 - - [06/Jun/2020 20:19:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:20:38] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:20:48] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:24:25] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:24:37] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:24:43] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:30:10] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:30:52] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:36:44] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:37:41] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:38:32] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:38:47] "POST /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2020 20:39:33] "POST /chart HTTP/1.1" 200 -
